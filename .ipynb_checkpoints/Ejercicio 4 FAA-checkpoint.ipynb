# %% [markdown]
# Ejercicio 4: Bonus
# Este ejercicio NO ES OBLIGATORIO. Para aquellos que necesiten un poco de adrenalina extra, les va este apartado. Deberán descubrir la palabra secreta, y enviarla junto con el código python para obtenerla

# %% [markdown]
# "El celular irrompible"
#
# QR: 32827777222444336622233288777787772555

# %%
from xml.etree import ElementTree
import pandas as pd
import shutil
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import skimage                 # form 1, load whole skimage library
import skimage.io              # form 2, load skimage.io module only
from skimage.io import imread  # form 3, load only the imread function
import numpy as np

# %%
pic = mpimg.imread('riddle.png')
plt.imshow(pic)
plt.show()

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Hight {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of Image {}'.format(pic.ndim))
#tenemos 3 layers: RGB
# Out:
# Type of the image :  <class 'numpy.ndarray'>
# Shape of the image : (1000, 1000, 3)
# Image Hight 1000
# Image Width 1000
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size)) 
print('Maximum RGB value in this image {}'.format(pic.max())) 
print('Minimum RGB value in this image {}'.format(pic.min()))
#importante; los valores No estan entre 0 y 255
# Out:
# Image size 3000000
# Maximum RGB value in this image 1.0
# Minimum RGB value in this image 0.0

# %%
# A specific pixel located at Row : 100 ; Column : 50  
# Each channel's value of it, gradually R , G , B  
print('Value of only R channel {}'.format(pic[ 100, 50, 0])) 
print('Value of only G channel {}'.format(pic[ 100, 50, 1])) 
print('Value of only B channel {}'.format(pic[ 100, 50, 2]))
# Out:
# Value of only R channel 0.09803921729326248
# Value of only G channel 0.01568627543747425
# Value of only B channel 0.7254902124404907

# %%
plt.title('R channel') 
plt.imshow(pic[ : , : , 0])
plt.show()
